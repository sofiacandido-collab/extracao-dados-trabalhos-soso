# %% [markdown]
# # Exercício 3 — Meu repositório de trabalhos vai para o GitHub
#
# Este é o entregável da Aula 3. Ele não pede código novo: pega o que você já construiu nas Aulas 1 e 2, dentro da pasta `extracao-dados-trabalhos-SeuNome`, e transforma isso em um repositório Git organizado, com histórico de commits, no GitHub, privado, com o usuário `mateuspestana` como colaborador.
#
# **ATENÇÃO, antes de qualquer comando:** este exercício acontece **fora** da pasta do material do curso (a que você clonou como `extracao_analise_2026` e atualiza com `git pull`). Você vai trabalhar dentro da sua pasta pessoal `extracao-dados-trabalhos-SeuNome`, criada na Aula 1. Nunca rode `git init`, `git add` ou `git commit` dentro da pasta do material do curso, ela é compartilhada e já tem o meu histórico. Antes de cada bloco de comandos, confira o caminho com `cd` (Windows) ou `pwd` (Mac): ele precisa terminar em `.../extracao-dados-trabalhos-SeuNome`, nunca em `.../extracao_analise_2026`. COPIE (Ctrl C) esse arquivo .ipynb para DENTRO da sua pasta 03 do projeto. Leia o notebook inteiro antes de começar a fazer.
#
# **Pontuação:** 1,0. Realização individual.

# %% [markdown]
# ## Parte 0 — Confira o que você já tem
#
# Você não vai recriar nada do zero. Confira, dentro de `extracao-dados-trabalhos-SeuNome/projetos/`, que já existem:
#
# - [ ] `01-ambiente/`, com `data/`, `src/`, `docs/` e um `README.md` (entrega da Aula 1).
# - [ ] `02-python-basico/`, com a leitura de CSV adaptada (entrega da Aula 2).
#
# Se alguma faltar, volte para a aula correspondente e complete a entrega antes de continuar. Este exercício só organiza e versiona o que já existe.
#
# **OBS:** se, ao seguir a seção 4 da Aula 3, o comando `mkdir` reclamou que `01-ambiente` ou `02-python-basico` já existe, tudo certo, é exatamente porque elas vieram das Aulas 1 e 2. Não é erro seu, só não crie essas pastas de novo aqui.

# %% [markdown]
# ## Parte 1 — Preparando os arquivos locais
#
# Abra no VS Code a pasta `extracao-dados-trabalhos-SeuNome` (**File > Open Folder**), não a pasta do material do curso. Confira na raiz dela, fora de `projetos/`:
#
# - `README.md`: se ainda não existe, crie e escreva um parágrafo curto sobre o que este repositório guarda.
# - `.gitignore`: se ainda não existe, crie com este conteúdo:
#
# ```text
# .venv/
# .env
# __pycache__/
# *.py[cod]
# .DS_Store
# Thumbs.db
# ```
#
# Agora crie a pasta da entrega desta aula, `projetos/03-git-github/`. Dentro dela, crie um `README.md` e responda:
#
# **Nome que vou dar ao repositório privado no GitHub:**
#
# > torta.
#
# **O que cada pasta representa, em uma frase cada:**
#
# > `01-ambiente`: chocolate.
# > `02-python-basico`: caramelo.
# > `03-git-github`: morango.
#
# **O que conferi no `.gitignore` antes do primeiro commit:**
#
# > Escreva aqui.

# %% [markdown]
# ## Parte 2 — Um commit por pasta
#
# Ainda dentro de `extracao-dados-trabalhos-SeuNome`, rode a sequência abaixo uma etapa de cada vez, conferindo o `git status` antes de cada commit. Se aparecer `.venv/`, `.env` ou algo que você não reconhece, pare e revise o `.gitignore` antes de continuar.
#
# **Estrutura inicial:**
#
# ```bash
# git init
# git status
# git add README.md .gitignore
# git status
# git commit -m "cria estrutura inicial do repositorio"
# ```
#
# **Entrega da Aula 1:**
#
# ```bash
# git add projetos/01-ambiente
# git status
# git commit -m "adiciona entrega da aula 1: ambiente e fontes"
# ```
#
# **Entrega da Aula 2:**
#
# ```bash
# git add projetos/02-python-basico
# git status
# git commit -m "adiciona entrega da aula 2: leitura de csv"
# ```
#
# **Entrega da Aula 3:**
#
# ```bash
# git add projetos/03-git-github
# git status
# git commit -m "adiciona entrega da aula 3: git e github"
# ```
#
# Rode `git log --oneline` e cole o resultado abaixo. Devem aparecer 4 commits.
#
# > 8d76cf2 (HEAD -> main, origin/main, origin/HEAD) altera README
# a14f9ba cria estrutura inicial dos trabalhos.

# %% [markdown]
# ## Parte 3 — Criando o repositório privado no GitHub
#
# 1. No GitHub, clique no `+` no canto superior direito e escolha **New repository**.
# 2. Dê o nome que você registrou na Parte 1, por exemplo `extracao-dados-trabalhos-seunome`.
# 3. Selecione **Private**.
# 4. Não marque nenhuma opção de criar `README`, `.gitignore` ou `license`: seu repositório local já tem tudo isso, e criar de novo no GitHub geraria conflito.
# 5. Clique em **Create repository** e deixe a página aberta, ela mostra a URL que você usa a seguir.
#
# De volta ao terminal, dentro de `extracao-dados-trabalhos-SeuNome`:
#
# ```bash
# git branch -M main
# git remote add origin <URL_DO_REPOSITORIO>
# git push -u origin main
# ```
#
# Atualize a página do GitHub. Você deve ver `README.md`, `.gitignore`, a pasta `projetos/` e os 4 commits no histórico.

# %% [markdown]
# ## Parte 4 — Me adicionando como colaborador
#
# O repositório é **privado**: por padrão, só você o vê. Para eu conseguir corrigir sem que a turma tenha acesso às suas respostas, adicione-me como colaborador direto no repositório, e não deixe o repositório público.
#
# 1. Na página do repositório no GitHub, clique em **Settings**.
# 2. No menu à esquerda, clique em **Collaborators** (pode pedir sua senha de novo).
# 3. Clique em **Add people**.
# 4. Digite `mateuspestana`, selecione o usuário na lista e confirme o convite.
#
# **OBS:** o convite fica pendente até eu aceitar, isso é normal e não depende de você. Não precisa reenviar nem se preocupar se ele não aparecer como colaborador imediatamente.
#
# **ATENÇÃO:** nunca troque a visibilidade do repositório para **Public** para "facilitar" a correção. Isso expõe suas respostas para a turma inteira. Se isso acontecer sem querer, vá em **Settings > General > Danger Zone > Change visibility** e volte para **Private** imediatamente.

# %% [markdown]
# ## Parte 5 — Conferência final
#
# Antes de considerar a entrega concluída, confira:
#
# - [ ] O repositório está **privado**.
# - [ ] `mateuspestana` aparece em **Settings > Collaborators**. Isso depende de eu aceitar o convite.
# - [ ] `git log --oneline` mostra 4 commits: estrutura inicial + um por pasta (01, 02 e 03).
# - [ ] `projetos/01-ambiente`, `projetos/02-python-basico` e `projetos/03-git-github` aparecem no GitHub.
# - [ ] Adicione esse .ipynb (COPIE, e não MOVA/ARRASTE) para a pasta `projetos/03-git-github`.
# - [ ] `.venv/`, `.env` e qualquer arquivo sensível **não** aparecem no repositório.
# - [ ] Nada foi commitado dentro da pasta do material do curso (`extracao_analise_2026`).
# - [ ] Esse notebook ainda existe dentro da pasta do curso (`extracao_analise_2026`).
#
# No `README.md` da raiz, registre o nome do repositório, o seu nome completo, e liste as entregas feitas (pasta 01, 02 e 03).
