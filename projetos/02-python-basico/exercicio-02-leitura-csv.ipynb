# %% [markdown]
# # Exercício 2 — Ler e conferir um CSV
#
# Este exercício pratica uma leitura linear: abrir → ler → contar → mostrar colunas. Abra a pasta `exercicios/` no VS Code antes de executar as células. O arquivo que vamos usar já está na pasta `data`. Antes de TUDO, copie a pasta `exercicios/` para dentro da sua pasta de entregas que você criou na aula (`extracao-analise-dados-SeuNome` - lembrando que é SEU nome, não o MEU nome! 🙃) dentro da pasta que inicia com 02 para ter isso registrado lá!

# %% [markdown]
# ## Preparação
#
# Se ainda não criou o ambiente desta pasta, siga a Aula 2. Abra este arquivo pelo VS Code e, no canto superior direito, selecione o interpretador da pasta `.venv`. Para notebooks, você executa as células pelo botão de reprodução; `uv run` será usado quando trabalharmos com scripts `.py`.
#
# O CSV já está em `data/publicacoes_exercicio.csv`. Abra-o antes de escrever código e confira o cabeçalho.

# %%
import csv

with open("data/publicacoes_exercicio.csv", encoding="utf-8", newline="") as arquivo:
    leitor = csv.DictReader(arquivo)
    linhas = list(leitor)
    colunas = leitor.fieldnames or []

# Substitua cada comentário por um print:
# Mostre o total de linhas de dados.
# Mostre os nomes das colunas separados por vírgula.

# %% [markdown]
# ## Como conferir
#
# Seu resultado deve informar 3 linhas de dados e as colunas `id`, `campanha`, `cliques` e `compartilhamentos`. Depois responda: qual coluna parece contar uma ação? Qual parece identificar cada registro?
#
# ## Para entregar
#
# 1. Salve o notebook com as duas linhas completas e executadas.
# 2. Acrescente, em uma célula Markdown, uma frase sobre o que os dados representam e uma limitação do conjunto.
# 3. No README da sua entrega, registre a fonte: “dados fictícios fornecidos para a Aula 2”.
# 4. Se usou IA, descreva o que ela sugeriu e como você conferiu o resultado.
