# %% [markdown]
# # Exercício 1 — Sua primeira investigação de fontes
#
# A missão da Aula 1 continua aqui, sozinho ou em dupla. Não será pontuado. Não existe uma única resposta certa; o que importa é que suas respostas sejam suas, específicas e verificáveis — nada de fonte ou dado inventado.
# Antes de TUDO, copie a pasta `exercicios/` para dentro da sua pasta de entregas que você criou na aula (`extracao-analise-dados-SeuNome` - lembrando que é SEU nome, não o MEU nome! 🙃) dentro de `01-ambiente` para ter isso registrado lá! E COPIE, ao invés de MOVER, para que você tenha essa cópia original sempre disponível.
#
# **OBS:** Desafio você a fazer pelo terminal. No Windows, o comando é `cp`. Logo, podemos fazer:
#
# ```cmd
# cp caminho_arquivo/arquivo.ext caminho_novo_arquivo/novo_arquivo.ext
# ```

# %% [markdown]
# ## Parte 1 — Minha base de operações
#
# Escreva o caminho até a pasta `01-ambiente` que você criou na aula e explique, com suas palavras, o que pretende guardar em cada subpasta.

# %% [markdown]
# **Caminho da minha pasta `01-ambiente`:**
#
# > Escreva aqui.
#
# **O que vou guardar em `data/`:**
#
# > Escreva aqui.
#
# **O que vou guardar em `src/`:**
#
# > Escreva aqui.
#
# **O que vou guardar em `docs/`:**
#
# > Escreva aqui.

# %% [markdown]
# ## Parte 2 — Uma fonte de verdade
#
# Escolha uma pergunta ligada a comunicação digital que te interessa de verdade: não precisa ser o nosso projeto final, só algo que você queira entender melhor. Pode inventar, mas precisa fazer sentido.
#
# Agora vá até a internet **agora** e encontre uma fonte real ligada a essa pergunta: um perfil público, um portal de dados, uma página institucional. Abra-a de fato antes de responder. Nada de imaginar como ela seria.

# %% [markdown]
# **Minha pergunta:**
#
# > Escreva aqui.
#
# **Fonte que encontrei (nome e link):**
#
# > Escreva aqui.
#
# **Quem publica essa fonte:**
#
# > Escreva aqui.
#
# **O que essa fonte me deixa observar:**
#
# > Escreva aqui.
#
# **O que essa fonte NÃO me deixa concluir:**
#
# > Escreva aqui.
#
# **Formato provável dos dados ali (estruturado, semiestruturado ou desestruturado) e por quê:**
#
# > Escreva aqui.

# %% [markdown]
# ## Parte 3 — Mais duas candidatas
#
# Para a mesma pergunta, indique duas outras fontes possíveis, se encontrar. Essas você pode só reconhecer de vista, sem precisar inspecionar com o mesmo cuidado da Parte 2. Evite prometer conclusões que a fonte não sustenta.

# %% [markdown]
# | Fonte candidata | Link ou onde encontrar | O que ela ajudaria a observar | Limitação que já imagino |
# | --- | --- | --- | --- |
# | 2. |  |  |  |
# | 3. |  |  |  |

# %% [markdown]
# ## Parte 4 — Conferência final
#
# 1. Confirme que `01-ambiente/` tem as pastas `data`, `src` e `docs`.
# 2. Crie (ou atualize) o arquivo `README.md` em `01-ambiente/` com a pergunta, a estrutura de pastas e as três fontes registradas aqui.
# 3. Salve este notebook dentro do seu projeto como evidência da investigação.
# 4. Se usou alguma ferramenta de IA em qualquer parte deste exercício, anote no README: qual ferramenta, para quê, e o que você conferiu depois de usar.
#
# Não há necessidade de código neste exercício: o produto é uma fonte real bem investigada e uma estrutura de projeto que faz sentido para ela.
